# %%
import pandas as pd

# %%
df= pd.read_csv(r"D:\vs code\pandas\weather\data\dehradun 2015-01-01 to 2015-12-31.csv")

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='str')

# %%
df.info()   # gives Structure- Data types and null values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              365 non-null    str
#  1   datetime          365 non-null    str
#  2   tempmax           365 non-null    float64
#  3   tempmin           365 non-null    float64
#  4   temp              365 non-null    float64
#  5   feelslikemax      365 non-null    float64
#  6   feelslikemin      365 non-null    float64
#  7   feelslike         365 non-null    float64
#  8   dew               365 non-null    float64
#  9   humidity          365 non-null    float64
#  10  precip            365 non-null    float64
#  11  precipprob        365 non-null    int64
#  12  precipcover       365 non-null    float64
#  13  preciptype        151 non-null    str
#  14  snow              365 non-null    int64
#  15  snowdepth         365 non-null    int64
# ...

# %%
df["datetime"].head() # view data-first five rows
# Out:
# 0    2015-01-01
# 1    2015-01-02
# 2    2015-01-03
# 3    2015-01-04
# 4    2015-01-05
# Name: datetime, dtype: str

# %% [markdown]
# Phase1: Understanding data

# %%
df.head()   #give first five rows
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  dehradun  2015-01-01     23.6      8.1  15.1          23.6           8.1
# 1  dehradun  2015-01-02     19.7     10.1  14.4          19.7          10.1
# 2  dehradun  2015-01-03     17.6     10.9  13.4          17.6          10.9
# 3  dehradun  2015-01-04     19.3      8.4  13.0          19.3           7.3
# 4  dehradun  2015-01-05     22.2      4.5  11.8          22.2           2.6
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       15.1   3.1      48.1  ...         12.6        6         NaN
# 1       14.4   7.3      65.3  ...          8.9        4         NaN
# 2       13.4  10.5      83.2  ...          7.9        4         NaN
# 3       12.8   8.0      74.5  ...         12.7        6         NaN
# 4       11.4   3.0      60.4  ...         13.8        6         NaN
#
#                sunrise               sunset  moonphase  \
# ...

# %%
df.columns  #give names of all columns in a list
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='str')

# %%
df.shape    #give the count of rows and columns
# Out:
# (365, 33)

# %%
df.info()  # gives a summary of the DataFrame.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              365 non-null    str
#  1   datetime          365 non-null    str
#  2   tempmax           365 non-null    float64
#  3   tempmin           365 non-null    float64
#  4   temp              365 non-null    float64
#  5   feelslikemax      365 non-null    float64
#  6   feelslikemin      365 non-null    float64
#  7   feelslike         365 non-null    float64
#  8   dew               365 non-null    float64
#  9   humidity          365 non-null    float64
#  10  precip            365 non-null    float64
#  11  precipprob        365 non-null    int64
#  12  precipcover       365 non-null    float64
#  13  preciptype        151 non-null    str
#  14  snow              365 non-null    int64
#  15  snowdepth         365 non-null    int64
# ...

# %%
df.describe()
# Out:
#           tempmax     tempmin        temp  feelslikemax  feelslikemin  \
# count  365.000000  365.000000  365.000000    365.000000    365.000000
# mean    29.634521   17.052877   22.798356     30.605205     16.950411
# std      6.236750    6.178127    6.350677      6.901218      6.372117
# min     14.900000    4.300000   10.500000     14.900000      2.600000
# 25%     25.500000   12.100000   17.900000     25.500000     12.100000
# 50%     29.900000   18.100000   24.400000     31.000000     18.100000
# 75%     32.500000   22.700000   27.300000     36.400000     22.700000
# max     43.600000   27.700000   35.300000     51.700000     29.400000
#
#         feelslike         dew    humidity      precip  precipprob  ...  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  ...
# mean    23.109863   12.824658   58.719726    4.895342   41.369863  ...
# std      6.671348    7.124362   16.426665   14.204523   49.317180  ...
# ...

# %% [markdown]
# Phase 2: Selecting Data

# %%
pd.set_option("display.max_rows",None)  #tells pandas to display everything 
df["temp"].head()   # displayes only 5 top rows of temp 
df["temp"]  #gives all rows data
# Out:
# 0      15.1
# 1      14.4
# 2      13.4
# 3      13.0
# 4      11.8
# 5      11.6
# 6      12.0
# 7      12.4
# 8      12.2
# 9      10.9
# 10     11.2
# 11     11.6
# 12     13.6
# 13     11.4
# 14     11.9
# 15     13.3
# 16     13.0
# 17     12.4
# 18     12.0
# 19     12.5
# 20     12.1
# 21     11.4
# 22     12.5
# 23     13.0
# 24     12.4
# 25     12.6
# 26     12.7
# 27     11.8
# 28     11.2
# 29     10.6
# 30     11.7
# 31     13.8
# 32     15.0
# 33     15.0
# 34     14.7
# 35     14.4
# 36     14.2
# 37     14.6
# 38     15.8
# 39     15.6
# 40     15.5
# 41     14.9
# 42     15.2
# 43     15.0
# 44     17.1
# 45     18.2
# 46     17.9
# 47     18.8
# 48     18.7
# 49     19.7
# 50     19.6
# 51     19.2
# 52     19.5
# 53     20.4
# 54     20.9
# 55     19.2
# 56     17.6
# 57     16.5
# 58     17.4
# 59     14.5
# 60     13.6
# 61     13.7
# 62     13.6
# 63     15.6
# 64     16.8
# 65     17.2
# 66     16.4
# 67     15.9
# 68     17.2
# 69     18.2
# 70     19.0
# ...

# %%
df["temp"].tail(10)  #gives last 5 rows, give a number in parenthesis of tail and it will give that many rows
# Out:
# 355    12.1
# 356    11.3
# 357    10.5
# 358    10.7
# 359    12.6
# 360    14.5
# 361    15.8
# 362    15.3
# 363    15.2
# 364    14.7
# Name: temp, dtype: float64

# %%
df["temp"].sample(4)    #it selects random rows and tells their index and value
# Out:
# 107    26.1
# 55     19.2
# 87     22.3
# 175    26.3
# Name: temp, dtype: float64

# %%
type(df["temp"])
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df["temp"].mean()
# Out:
# np.float64(22.79835616438356)

# %%
df[["datetime","temp"]].head()  #selects 2 columns and merges them their type is dataframe not series
# Out:
#      datetime  temp
# 0  2015-01-01  15.1
# 1  2015-01-02  14.4
# 2  2015-01-03  13.4
# 3  2015-01-04  13.0
# 4  2015-01-05  11.8

# %%
type(df[["datetime", "temp"]])
# Out:
# pandas.DataFrame

# %% [markdown]
# Filtering Rows

# %%
df["temp"]>30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
hot_days= df[df["temp"] > 30]

# %%
hot_days.head()
# Out:
#          name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 125  dehradun  2015-05-06     38.9     20.9  30.5          36.7          20.9
# 126  dehradun  2015-05-07     39.7     23.2  31.5          37.7          23.2
# 127  dehradun  2015-05-08     40.2     23.7  31.4          37.9          23.7
# 128  dehradun  2015-05-09     39.4     23.7  31.7          37.9          23.7
# 129  dehradun  2015-05-10     39.7     24.4  31.9          39.2          24.4
#
#      feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 125       29.8  11.5      34.0  ...         27.2       10         NaN
# 126       30.8  12.0      32.7  ...         27.0       10         NaN
# 127       30.6  11.6      32.5  ...         25.8        9         NaN
# 128       30.8  11.2      30.7  ...         25.7       10         NaN
# 129       31.5  12.8      33.4  ...         25.5        9         NaN
#
# ...

# %%
hot_days.shape
# Out:
# (48, 33)

# %%
hot_days.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 48 entries, 125 to 184
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              48 non-null     str
#  1   datetime          48 non-null     str
#  2   tempmax           48 non-null     float64
#  3   tempmin           48 non-null     float64
#  4   temp              48 non-null     float64
#  5   feelslikemax      48 non-null     float64
#  6   feelslikemin      48 non-null     float64
#  7   feelslike         48 non-null     float64
#  8   dew               48 non-null     float64
#  9   humidity          48 non-null     float64
#  10  precip            48 non-null     float64
#  11  precipprob        48 non-null     int64
#  12  precipcover       48 non-null     float64
#  13  preciptype        16 non-null     str
#  14  snow              48 non-null     int64
#  15  snowdepth         48 non-null     int64
# ...
